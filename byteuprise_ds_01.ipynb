# %% [markdown]
# <a href="https://colab.research.google.com/github/ChetanMestry3074/Byteuprize-project/blob/main/byteuprise_ds_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("/content/svm_data.csv")

# %%
df.head()
# Out:
#          x1        x2  y
# 0  0.486861  0.163756  0
# 1  0.590718  0.429319  0
# 2  0.537981  0.082374  0
# 3  0.184411  0.717404  1
# 4  0.825697  0.414670  1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['x1'].plot(kind='hist', bins=20, title='x1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['x2'].plot(kind='hist', bins=20, title='x2')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['y'].plot(kind='hist', bins=20, title='y')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
df['x1'].plot(kind='hist', bins=20, title='Histogram of age',color='r',edgecolor='blue')
plt.show()
